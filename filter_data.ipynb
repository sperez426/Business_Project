# %%
import pandas as pd

# %%
df = pd.read_csv('Iowa_Liquor_Sales.csv')
# Out:
# /Users/sheraleelovejoy/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S29198800001  11/20/2015          2191
# 1        S29195400002  11/21/2015          2205
# 2        S29050300001  11/16/2015          3549
# 3        S28867700001  11/04/2015          2513
# 4        S29050800001  11/17/2015          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Invoice/Item Number    object
#  1   Date                   object
#  2   Store Number           int64
#  3   Store Name             object
#  4   Address                object
#  5   City                   object
#  6   Zip Code               object
#  7   Store Location         object
#  8   County Number          float64
#  9   County                 object
#  10  Category               float64
#  11  Category Name          object
#  12  Vendor Number          float64
#  13  Vendor Name            object
#  14  Item Number            int64
#  15  Item Description       object
#  16  Pack                   int64
#  17  Bottle Volume (ml)     int64
#  18  State Bottle Cost      object
#  19  State Bottle Retail    object
#  20  Bottles Sold           int64
# ...

# %%
df1 = df.drop(['Invoice/Item Number','Store Number','County Number','County','Vendor Number','Pack','Volume Sold (Gallons)','Category','Category Name'], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 15 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Date                  object
#  1   Store Name            object
#  2   Address               object
#  3   City                  object
#  4   Zip Code              object
#  5   Store Location        object
#  6   Vendor Name           object
#  7   Item Number           int64
#  8   Item Description      object
#  9   Bottle Volume (ml)    int64
#  10  State Bottle Cost     object
#  11  State Bottle Retail   object
#  12  Bottles Sold          int64
#  13  Sale (Dollars)        object
#  14  Volume Sold (Liters)  float64
# dtypes: float64(1), int64(3), object(11)
# memory usage: 1.4+ GB

# %%
df1['Date']
# Out:
# 0           11/20/2015
# 1           11/21/2015
# 2           11/16/2015
# 3           11/04/2015
# 4           11/17/2015
#                ...
# 12591072    10/31/2017
# 12591073    10/31/2017
# 12591074    10/31/2017
# 12591075    10/31/2017
# 12591076    10/31/2017
# Name: Date, Length: 12591077, dtype: object

# %%
df1['Year']=pd.DatetimeIndex(df1['Date']).year

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12591077 entries, 0 to 12591076
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Date                  object
#  1   Store Name            object
#  2   Address               object
#  3   City                  object
#  4   Zip Code              object
#  5   Store Location        object
#  6   Vendor Name           object
#  7   Item Number           int64
#  8   Item Description      object
#  9   Bottle Volume (ml)    int64
#  10  State Bottle Cost     object
#  11  State Bottle Retail   object
#  12  Bottles Sold          int64
#  13  Sale (Dollars)        object
#  14  Volume Sold (Liters)  float64
#  15  Year                  int64
# dtypes: float64(1), int64(4), object(11)
# memory usage: 1.5+ GB

# %%
df1['Year']
# Out:
# 0           2015
# 1           2015
# 2           2015
# 3           2015
# 4           2015
#             ...
# 12591072    2017
# 12591073    2017
# 12591074    2017
# 12591075    2017
# 12591076    2017
# Name: Year, Length: 12591077, dtype: int64

# %%
mask = ((df1['Year'] == 2015))
new_df = df1[mask]

# %%
new_df['Year']
# Out:
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015
#            ...
# 8428097    2015
# 8428098    2015
# 8428099    2015
# 8428100    2015
# 8428101    2015
# Name: Year, Length: 2184483, dtype: int64

# %%
new_df.to_csv('iowa_sales.csv')

# %%
df2 = pd.read_csv('iowa_sales.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0        Date                        Store Name  \
# 0           0  11/20/2015                    Keokuk Spirits
# 1           1  11/21/2015            Ding's Honk And Holler
# 2           2  11/16/2015              Quicker Liquor Store
# 3           3  11/04/2015  Hy-Vee Food Store #2 / Iowa City
# 4           4  11/17/2015                  Twin Town Liquor
#
#                Address          City Zip Code  \
# 0            1013 MAIN        KEOKUK    52632
# 1     900 E WASHINGTON      CLARINDA    51632
# 2         1414 48TH ST  FORT MADISON    52627
# 3       812  S 1ST AVE     IOWA CITY    52240
# 4  104 HIGHWAY 30 WEST        TOLEDO    52342
#
#                                       Store Location  \
# 0    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)
# 1  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...
# 2  1414 48TH ST\nFORT MADISON 52627\n(40.624226, ...
# 3                   812 S 1ST AVE\nIOWA CITY 52240\n
# ...

# %%
mask1 = (df2['City'] == ('BETTENDORF'))
final_df = df2[mask1]

# %%
final_df['City']
# Out:
# 254        BETTENDORF
# 319        BETTENDORF
# 379        BETTENDORF
# 521        BETTENDORF
# 662        BETTENDORF
#               ...
# 2184304    BETTENDORF
# 2184307    BETTENDORF
# 2184393    BETTENDORF
# 2184418    BETTENDORF
# 2184471    BETTENDORF
# Name: City, Length: 29591, dtype: object

# %%
final_df.head()
# Out:
#      Unnamed: 0        Date                            Store Name  \
# 254         765  11/18/2015  Hy-Vee Wine and Spirits / Bettendorf
# 319        1066  11/20/2015             Tobacco 4 Less / State St
# 379        1307  05/04/2015                         Lot-A-Spirits
# 521        1901  03/09/2015                         Lot-A-Spirits
# 662        2457  04/01/2015  Hy-Vee Wine and Spirits / Bettendorf
#
#                    Address        City Zip Code  \
# 254  2890 DEVILS GLEN ROAD  BETTENDORF    52722
# 319          1032 STATE ST  BETTENDORF    52722
# 379          3780 STATE ST  BETTENDORF    52722
# 521          3780 STATE ST  BETTENDORF    52722
# 662  2890 DEVILS GLEN ROAD  BETTENDORF    52722
#
#                                         Store Location  \
# 254  2890 DEVILS GLEN ROAD\nBETTENDORF 52722\n(41.5...
# 319  1032 STATE ST\nBETTENDORF 52722\n(41.525027, -...
# 379  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
# ...

# %%
mask2 = (df2['Store Name'] == ('Lot-A-Spirits'))
final_df = df2[mask2]

# %%
final_df.head()
# Out:
#       Unnamed: 0        Date     Store Name        Address        City  \
# 379         1307  05/04/2015  Lot-A-Spirits  3780 STATE ST  BETTENDORF
# 521         1901  03/09/2015  Lot-A-Spirits  3780 STATE ST  BETTENDORF
# 787         2949  09/02/2015  Lot-A-Spirits  3780 STATE ST  BETTENDORF
# 1175        4629  01/12/2015  Lot-A-Spirits  3780 STATE ST  BETTENDORF
# 1249        4969  09/21/2015  Lot-A-Spirits  3780 STATE ST  BETTENDORF
#
#      Zip Code                                     Store Location  \
# 379     52722  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
# 521     52722  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
# 787     52722  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
# 1175    52722  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
# 1249    52722  3780 STATE ST\nBETTENDORF 52722\n(41.529655, -...
#
#                           Vendor Name  Item Number Item Description  \
# 379             Sazerac North America         8827         Lauder's
# ...

# %%
print(len(pd.unique(final_df['Item Description'])))
# Out:
# 598

# %%
bottles_df = final_df.groupby('Item Description')['Bottles Sold'].sum()

# %%
bottles_df
# Out:
# Item Description
# 1800 Coconut                    28
# 1800 Reposado                  342
# 1800 Reposado Tequila          180
# 1800 Silver                     78
# 1800 Silver Tequila             28
#                               ...
# Wiser's Rye                      2
# Wolfschmidt                     84
# Woodford Reserve Bourbon       210
# Yukon Jack Canadian Liqueur    192
# Zyr Vodka                        2
# Name: Bottles Sold, Length: 598, dtype: int64

# %%
bottles_df.to_csv('bottle_sales.csv')

# %%
final_df.to_csv('final_iowa_sales.csv')
